# %%
import pandas as pd
from datetime import datetime, timedelta
import numpy as np

# %% [markdown]
# # Import Data

# %%
dateparse = lambda x: datetime.strptime(x, '%m/%d/%Y %H:%M')

# %%
geographic_data = pd.read_csv("./Data/geographic_data.csv") 
airport_data = pd.read_csv("./Data/training_set_airport_data.csv", parse_dates=['Flight Datetime','AOBT','ATOT'], date_parser=dateparse)
weather_data = pd.read_csv("./Data/weather_data.csv", parse_dates=['time_hourly'], date_parser=dateparse)
#aircraft_data = pd.ExcelFile("./Data/ACchar.xlsx")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## 1. Main training file

# %%
# Clean airport_data column names
airport_data.columns = airport_data.columns.str.replace(' ', '_')
# Create time columns
airport_data['hour'] = airport_data['Flight_Datetime'].map(lambda d: d.hour)
airport_data['minute'] = airport_data['Flight_Datetime'].map(lambda d: d.minute)
airport_data['year'] = airport_data['Flight_Datetime'].map(lambda d: d.year)
airport_data['month'] = airport_data['Flight_Datetime'].map(lambda d: d.month)
airport_data['day'] = airport_data['Flight_Datetime'].map(lambda d: d.day)
airport_data
# Out:
#            Flight_Datetime       Aircraft_Model                AOBT  \
# 0      2015-01-01 06:00:00    B737-800 WINGLETS 2015-01-01 05:56:00
# 1      2015-01-01 06:10:00         A320-100/200 2015-01-01 06:08:00
# 2      2015-01-01 06:15:00         A320-100/200 2015-01-01 06:08:00
# 3      2015-01-01 06:20:00         A320-100/200 2015-01-01 06:24:00
# 4      2015-01-01 06:20:00                 A319 2015-01-01 06:14:00
# ...                    ...                  ...                 ...
# 543808 2018-12-31 21:15:00             A350-900 2018-12-31 21:02:00
# 543809 2018-12-31 21:30:00             B787-900 2018-12-31 21:24:00
# 543810 2018-12-31 21:50:00             A330-200 2018-12-31 22:27:00
# 543811 2018-12-31 22:10:00  B787-800 Dreamliner 2018-12-31 22:09:00
# 543812 2018-12-31 23:55:00             B787-900 2018-12-31 23:58:00
#
#                       ATOT      Stand    Runway  hour  minute  year  month  \
# 0      2015-01-01 06:05:00   STAND_62  RUNWAY_4     6       0  2015      1
# 1      2015-01-01 06:18:00  STAND_153  RUNWAY_4     6      10  2015      1
# 2      2015-01-01 06:19:00   STAND_44  RUNWAY_2     6      15  2015      1
# 3      2015-01-01 06:36:00    STAND_7  RUNWAY_3     6      20  2015      1
# 4      2015-01-01 06:27:00   STAND_17  RUNWAY_2     6      20  2015      1
# ...                    ...        ...       ...   ...     ...   ...    ...
# 543808 2018-12-31 21:20:00  STAND_150  RUNWAY_3    21      15  2018     12
# 543809 2018-12-31 21:38:00   STAND_77  RUNWAY_1    21      30  2018     12
# 543810 2018-12-31 22:37:00  STAND_120  RUNWAY_1    21      50  2018     12
# 543811 2018-12-31 22:29:00   STAND_49  RUNWAY_2    22      10  2018     12
# 543812 2019-01-01 00:11:00   STAND_12  RUNWAY_4    23      55  2018     12
#
#         day
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 543808   31
# 543809   31
# 543810   31
# 543811   31
# 543812   31
#
# [543813 rows x 11 columns]

# %%
# Create dependent variable
airport_data['taxi_time']= airport_data['ATOT'] - airport_data['AOBT']
airport_data['taxi_seconds']= airport_data['taxi_time']/ np.timedelta64(1, 'm')*60

# %%
airport_data
# Out:
#            Flight_Datetime       Aircraft_Model                AOBT  \
# 0      2015-01-01 06:00:00    B737-800 WINGLETS 2015-01-01 05:56:00
# 1      2015-01-01 06:10:00         A320-100/200 2015-01-01 06:08:00
# 2      2015-01-01 06:15:00         A320-100/200 2015-01-01 06:08:00
# 3      2015-01-01 06:20:00         A320-100/200 2015-01-01 06:24:00
# 4      2015-01-01 06:20:00                 A319 2015-01-01 06:14:00
# ...                    ...                  ...                 ...
# 543808 2018-12-31 21:15:00             A350-900 2018-12-31 21:02:00
# 543809 2018-12-31 21:30:00             B787-900 2018-12-31 21:24:00
# 543810 2018-12-31 21:50:00             A330-200 2018-12-31 22:27:00
# 543811 2018-12-31 22:10:00  B787-800 Dreamliner 2018-12-31 22:09:00
# 543812 2018-12-31 23:55:00             B787-900 2018-12-31 23:58:00
#
#                       ATOT      Stand    Runway  hour  minute  year  month  \
# 0      2015-01-01 06:05:00   STAND_62  RUNWAY_4     6       0  2015      1
# 1      2015-01-01 06:18:00  STAND_153  RUNWAY_4     6      10  2015      1
# 2      2015-01-01 06:19:00   STAND_44  RUNWAY_2     6      15  2015      1
# 3      2015-01-01 06:36:00    STAND_7  RUNWAY_3     6      20  2015      1
# 4      2015-01-01 06:27:00   STAND_17  RUNWAY_2     6      20  2015      1
# ...                    ...        ...       ...   ...     ...   ...    ...
# 543808 2018-12-31 21:20:00  STAND_150  RUNWAY_3    21      15  2018     12
# 543809 2018-12-31 21:38:00   STAND_77  RUNWAY_1    21      30  2018     12
# 543810 2018-12-31 22:37:00  STAND_120  RUNWAY_1    21      50  2018     12
# 543811 2018-12-31 22:29:00   STAND_49  RUNWAY_2    22      10  2018     12
# 543812 2019-01-01 00:11:00   STAND_12  RUNWAY_4    23      55  2018     12
#
#         day       taxi_time  taxi_seconds
# 0         1 0 days 00:09:00         540.0
# 1         1 0 days 00:10:00         600.0
# 2         1 0 days 00:11:00         660.0
# 3         1 0 days 00:12:00         720.0
# 4         1 0 days 00:13:00         780.0
# ...     ...             ...           ...
# 543808   31 0 days 00:18:00        1080.0
# 543809   31 0 days 00:14:00         840.0
# 543810   31 0 days 00:10:00         600.0
# 543811   31 0 days 00:20:00        1200.0
# 543812   31 0 days 00:13:00         780.0
#
# [543813 rows x 13 columns]

# %% [markdown]
# ## 2. Geographical data

# %%
#transform stand to upper case
geographic_data["stand"] = geographic_data["stand"].str.upper()

#produce a pd runway 
runway_data = geographic_data.iloc[:, 0:3]
runway_data.drop_duplicates(keep="first",inplace=True) 

#produce a pd stand
stand_data = geographic_data.iloc[:, 3:6]
stand_data.drop_duplicates(keep="first",inplace=True)

# %%
runway_data
# Out:
#          runway  Lat_runway  Lng_runway
# 0      RUNWAY_1   54.755307   -0.023040
# 1      RUNWAY_2   54.757120   -0.024107
# 1805   RUNWAY_3   54.761173    0.019840
# 11680  RUNWAY_4   54.761493    0.008320

# %%
stand_data
# Out:
#            stand  Lat_stand  Lng_stand
# 0        STAND_0  54.764575   0.000356
# 1        STAND_1  54.764690   0.024353
# 2        STAND_2  54.769141   0.011816
# 3        STAND_3  54.772184   0.006803
# 4        STAND_4  54.767007   0.008593
# ...          ...        ...        ...
# 14492  STAND_162  54.764551   0.007704
# 15938  STAND_163  54.765164   0.003849
# 16345  STAND_164  54.769665   0.007627
# 16689  STAND_165  54.772145   0.005333
# 16942  STAND_166  54.765950   0.000601
#
# [167 rows x 3 columns]

# %%
#Left join airport with geographic data on "runway" & "stand"
train_data= pd.merge(airport_data, runway_data, how="left", left_on="Runway", right_on= "runway")
train_data= pd.merge(train_data, stand_data, how="left", left_on="Stand", right_on= "stand")

# %%
train_data.drop(['runway','stand','taxi_time'], axis=1, inplace=True)
list(train_data.columns)
# Out:
# ['Flight_Datetime',
#  'Aircraft_Model',
#  'AOBT',
#  'ATOT',
#  'Stand',
#  'Runway',
#  'hour',
#  'minute',
#  'year',
#  'month',
#  'day',
#  'taxi_seconds',
#  'Lat_runway',
#  'Lng_runway',
#  'Lat_stand',
#  'Lng_stand']

# %% [markdown]
# ## 3. Weather data

# %%
# drop the duplicates line in weather_data
weather_data.drop_duplicates(keep="first",inplace=True)

weather_data
# Out:
#                time_hourly        summary                 icon  \
# 0      2015-01-01 06:00:00  Mostly Cloudy  partly-cloudy-night
# 10     2015-01-01 07:00:00  Mostly Cloudy  partly-cloudy-night
# 45     2015-01-01 08:00:00  Mostly Cloudy  partly-cloudy-night
# 68     2015-01-01 09:00:00       Overcast               cloudy
# 87     2015-01-01 10:00:00       Overcast               cloudy
# ...                    ...            ...                  ...
# 678868 2019-12-31 19:00:00  Mostly Cloudy  partly-cloudy-night
# 678878 2019-12-31 20:00:00  Partly Cloudy  partly-cloudy-night
# 678893 2019-12-31 21:00:00          Clear          clear-night
# 678898 2019-12-31 22:00:00          Clear          clear-night
# 678901 2019-12-31 23:00:00  Partly Cloudy  partly-cloudy-night
#
#         precipIntensity  precipProbability  temperature  apparentTemperature  \
# 0                   0.0                0.0        44.65                39.29
# 10                  0.0                0.0        45.62                40.50
# 45                  0.0                0.0        45.67                39.74
# 68                  0.0                0.0        44.65                38.44
# 87                  0.0                0.0        44.65                38.89
# ...                 ...                ...          ...                  ...
# 678868              0.0                0.0        44.49                38.74
# 678878              0.0                0.0        44.39                39.13
# 678893              0.0                0.0        44.17                39.56
# 678898              0.0                0.0        42.40                37.00
# 678901              0.0                0.0        39.11                33.69
#
#         dewPoint  humidity  pressure  windSpeed  windGust  windBearing  \
# 0          42.80      0.93    1031.6      10.29     11.39        210.0
# 10         42.80      0.90    1031.0      10.29     14.75        191.0
# 45         42.80      0.90    1030.9      12.76     13.52        210.0
# 68         42.80      0.93    1031.5      12.76     16.55        210.0
# 87         42.80      0.93    1030.7      11.39     12.95        191.0
# ...          ...       ...       ...        ...       ...          ...
# 678868     41.55      0.89    1031.7      11.24     18.59         91.0
# 678878     42.47      0.93    1031.7       9.89     19.32         92.0
# 678893     39.23      0.83    1031.8       8.25     20.27        102.0
# 678898     40.55      0.93    1031.7       9.11     19.94         93.0
# 678901     38.90      0.99    1031.5       7.67     17.22        114.0
#
#         cloudCover  uvIndex  visibility precipType  precipAccumulation  ozone
# 0             0.75      0.0       5.859       None                 0.0  310.4
# 10            0.75      0.0       5.591       None                 0.0  310.4
# 45            0.75      0.0       5.272       None                 0.0  310.4
# 68            1.00      0.0       3.730       None                 0.0  310.4
# 87            1.00      0.0       3.730       None                 0.0  310.4
# ...            ...      ...         ...        ...                 ...    ...
# 678868        0.75      0.0       6.933       None                 0.0  316.3
# 678878        0.51      0.0       7.456       None                 0.0  315.5
# 678893        0.26      0.0       6.391       None                 0.0  313.3
# 678898        0.08      0.0      10.000       None                 0.0  311.6
# 678901        0.37      0.0      10.000       None                 0.0  311.7
#
# [33866 rows x 19 columns]

# %%
#Create new column rounding flight datetime to nearest hour for mapping
def hour_rounder(t):
    # Rounds to nearest hour by adding a timedelta hour if minute >= 30
    return (t.replace(second=0, microsecond=0, minute=0, hour=t.hour)
               +timedelta(hours=t.minute//30))

train_data["Flight_Datetime_map"] = train_data["Flight_Datetime"].map(lambda d: hour_rounder(d))

#Left join train data with weather data on "Flight_Datetime_map" & "time_hourly"
train_data= pd.merge(train_data, weather_data, how="left", left_on="Flight_Datetime_map", right_on= "time_hourly")

# %%
# Need to handle 76 NaN value in weather 
# => we can use fill method from last flight as mostly midnight 22:00+ data is missing
null_data= train_data[(train_data.time_hourly.isnull())]
null_data[['Flight_Datetime_map', 'Flight_Datetime','time_hourly']]
# Out:
#        Flight_Datetime_map     Flight_Datetime time_hourly
# 1361   2015-01-05 03:00:00 2015-01-05 02:30:00         NaT
# 3065   2015-01-11 01:00:00 2015-01-11 00:30:00         NaT
# 4687   2015-01-16 23:00:00 2015-01-16 22:30:00         NaT
# 9070   2015-02-02 01:00:00 2015-02-02 00:30:00         NaT
# 15016  2015-02-22 03:00:00 2015-02-22 02:30:00         NaT
# ...                    ...                 ...         ...
# 518235 2018-10-15 01:00:00 2018-10-15 00:30:00         NaT
# 522548 2018-10-26 01:00:00 2018-10-26 00:30:00         NaT
# 529788 2018-11-16 23:00:00 2018-11-16 22:30:00         NaT
# 534052 2018-11-30 23:00:00 2018-11-30 22:30:00         NaT
# 541318 2018-12-24 01:00:00 2018-12-24 00:30:00         NaT
#
# [76 rows x 3 columns]

# %%
train_data.fillna(method='ffill', inplace=True)

# %%
train_data.drop(['Flight_Datetime_map','time_hourly','Flight_Datetime'], axis=1, inplace=True)
list(train_data.columns)
# Out:
# ['Aircraft_Model',
#  'AOBT',
#  'ATOT',
#  'Stand',
#  'Runway',
#  'hour',
#  'minute',
#  'year',
#  'month',
#  'day',
#  'taxi_seconds',
#  'Lat_runway',
#  'Lng_runway',
#  'Lat_stand',
#  'Lng_stand',
#  'summary',
#  'icon',
#  'precipIntensity',
#  'precipProbability',
#  'temperature',
#  'apparentTemperature',
#  'dewPoint',
#  'humidity',
#  'pressure',
#  'windSpeed',
#  'windGust',
#  'windBearing',
#  'cloudCover',
#  'uvIndex',
#  'visibility',
#  'precipType',
#  'precipAccumulation',
#  'ozone']

# %% [markdown]
# ## 4. Aircraft data

# %% [markdown]
# # Export for Preprocessing + FE

# %%
train_data.shape
# Out:
# (543813, 33)

# %%
train_data.isna().any() #=> all False can export
# Out:
# Aircraft_Model         False
# AOBT                   False
# ATOT                   False
# Stand                  False
# Runway                 False
# hour                   False
# minute                 False
# year                   False
# month                  False
# day                    False
# taxi_seconds           False
# Lat_runway             False
# Lng_runway             False
# Lat_stand              False
# Lng_stand              False
# summary                False
# icon                   False
# precipIntensity        False
# precipProbability      False
# temperature            False
# apparentTemperature    False
# dewPoint               False
# humidity               False
# pressure               False
# windSpeed              False
# windGust               False
# windBearing            False
# cloudCover             False
# uvIndex                False
# visibility             False
# precipType             False
# precipAccumulation     False
# ozone                  False
# dtype: bool

# %%
train_data.to_csv(f"./Data/merged.csv", index=False)
